# %%
# Init

from __future__ import division
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
export_df = pd.read_csv('../unzipped_shp_and_shx_shape_files/export.csv', na_values=".")

# %%
export_df.head()
# Out:
#    fips     county_zip_file_name  roads_length_m  intersections  \
# 0  1001  tl_2020_01001_roads.zip     2658136.223           4926
# 1  1003  tl_2020_01003_roads.zip     6818407.996          17393
# 2  1005  tl_2020_01005_roads.zip     2025010.112           2918
# 3  1007  tl_2020_01007_roads.zip     1957160.039           3039
# 4  1009  tl_2020_01009_roads.zip     2615906.457           4195
#
#                 countyname  population  state  county  area_land_sqm  \
# 0  Autauga County, Alabama       58805      1       1   1.539631e+09
# 1  Baldwin County, Alabama      231767      1       3   4.117725e+09
# 2  Barbour County, Alabama       25223      1       5   2.292160e+09
# 3     Bibb County, Alabama       22293      1       7   1.612189e+09
# 4   Blount County, Alabama       59134      1       9   1.670259e+09
#
#    area_water_sqm  ...  suicide_deaths  suicide_data_total_population  \
# 0    2.567754e+07  ...           190.0                      1143294.0
# ...

# %%
export_df['log_intersects_per_road_length'] = np.log(export_df['intersects_per_road_length'])

# %%
lm_rep = smf.ols(formula = 'log_intersects_per_road_length ~ B09001_population_under_3+B09001_population_3_to_4+B09001_population_5+B09001_population_6_to_8+B09001_population_9_to_11+B09001_population_12_to_14+B09001_population_15_to_17+B09001_population_under_18_total', data = export_df).fit()
print (lm_rep.summary())
# Out:
#                                   OLS Regression Results
# ...
# Dep. Variable:     log_intersects_per_road_length   R-squared:                       0.162
# Model:                                        OLS   Adj. R-squared:                  0.160
# Method:                             Least Squares   F-statistic:                     86.49
# Date:                            Wed, 02 Nov 2022   Prob (F-statistic):          1.93e-115
# Time:                                    10:17:49   Log-Likelihood:                -1619.8
# No. Observations:                            3143   AIC:                             3256.
# Df Residuals:                                3135   BIC:                             3304.
# Df Model:                                       7
# Covariance Type:                        nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
lm_rep = smf.ols(formula = 'log_intersects_per_road_length ~ S2302_families_no_worker', data = export_df).fit()
print (lm_rep.summary())
# Out:
#                                   OLS Regression Results
# ...
# Dep. Variable:     log_intersects_per_road_length   R-squared:                       0.177
# Model:                                        OLS   Adj. R-squared:                  0.177
# Method:                             Least Squares   F-statistic:                     677.1
# Date:                            Wed, 02 Nov 2022   Prob (F-statistic):          2.40e-135
# Time:                                    10:19:29   Log-Likelihood:                -1590.5
# No. Observations:                            3143   AIC:                             3185.
# Df Residuals:                                3141   BIC:                             3197.
# Df Model:                                       1
# Covariance Type:                        nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
lm_rep = smf.ols(formula = 'intersects_per_road_length ~ DP04_vehicles_0 + DP04_vehicles_1 + DP04_vehicles_2 + DP04_vehicles_3_or_more + DP04_vehicles_housing_total', data = export_df).fit()
print (lm_rep.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     intersects_per_road_length   R-squared:                       0.314
# Model:                                    OLS   Adj. R-squared:                  0.313
# Method:                         Least Squares   F-statistic:                     287.7
# Date:                        Wed, 02 Nov 2022   Prob (F-statistic):          6.91e-254
# Time:                                10:20:55   Log-Likelihood:                -3888.9
# No. Observations:                        3143   AIC:                             7790.
# Df Residuals:                            3137   BIC:                             7826.
# Df Model:                                   5
# Covariance Type:                    nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# ...

# %%
lm_rep = smf.ols(formula = 'log_intersects_per_road_length ~ DP04_vehicles_0 + DP04_vehicles_1 + DP04_vehicles_2 + DP04_vehicles_3_or_more + DP04_vehicles_housing_total', data = export_df).fit()
print (lm_rep.summary())
# Out:
#                                   OLS Regression Results
# ...
# Dep. Variable:     log_intersects_per_road_length   R-squared:                       0.300
# Model:                                        OLS   Adj. R-squared:                  0.299
# Method:                             Least Squares   F-statistic:                     269.0
# Date:                            Wed, 02 Nov 2022   Prob (F-statistic):          7.28e-240
# Time:                                    10:20:35   Log-Likelihood:                -1336.7
# No. Observations:                            3143   AIC:                             2685.
# Df Residuals:                                3137   BIC:                             2722.
# Df Model:                                       5
# Covariance Type:                        nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# # Analysing American Community Survey Data
# List of variables found in comments of this cell's markdown
# <!--
# S2302_families_no_worker
# S2302_families_no_worker_percent
# S2303_population_16_to_64_no_work
# S2303_population_16_to_64_no_work_percent
# S2303_population_16_to_64_total
# S1901_households_mean_income
# S1901_households_median_income
# S1901_households_total
# S1101_household_1_unit_structure
# S1101_household_2_unit_structure
# S1101_household_average_size
# S1101_household_living_alone
# S1101_household_living_alone_over_65
# S1101_household_mobile_misc_homes
# S1101_household_one_or_more_over_60
# S1101_household_one_or_more_under_18
# S1101_household_total_married
# S1101_household_with_under_18
# S1101_households_total
# S1401_population_enrolled_in_graduate
# S1401_population_enrolled_in_preschool
# S1401_population_enrolled_in_school
# S1401_population_enrolled_in_standardschool
# S1401_population_enrolled_in_undergraduate
# S1701_population_poverty_18_to_64
# S1701_population_poverty_female
# S1701_population_poverty_male
# S1701_population_poverty_over_65
# S1701_population_poverty_over25_baschelors_degree
# S1701_population_poverty_over25_highschool
# S1701_population_poverty_over25_no_highschool
# S1701_population_poverty_over25_some_college
# S1701_population_poverty_over25_total
# S1701_population_poverty_total
# S1701_population_poverty_under_18
# S1702_family_poverty_home_owner
# S1702_family_poverty_home_renter
# S1702_family_poverty_total
# S1301_omen_total_15_to_50
# S1501_population_over_25_completed_graduate
# S1501_population_over_25_completed_highschool
# S1501_population_over_25_completed_undergraduate
# S1501_population_over_25_some_highschool
# S1501_population_over_25_some_undergraduates
# S1501_population_over_25_total
# S2501_household_total
# S2501_household_with_relative_under_18
# S2502_household_moved_into_1990_to_1999
# S2502_household_moved_into_2000_to_2009
# S2502_household_moved_into_2010_to_2014
# S2502_household_moved_into_2015_to_2018
# S2502_household_moved_into_after_2019
# S2502_household_moved_into_before_1989
# S2502_householder_age_35_to_44
# S2502_householder_age_45_to_54
# S2502_householder_age_55_to_64
# S2502_householder_age_65_to_74
# S2502_householder_age_75_to_84
# S2502_householder_age_over_85
# S2502_householder_age_under_35
# S2502_householder_education_highschool
# S2502_householder_education_no_highschool
# S2502_householder_education_over_undergraduates
# S2502_householder_education_some_college_or_associates
# S2502_households_occupied_total
# S2503_households_percemt_median_income
# S2503_households_percemt_total
# S2503_households_percemt_with_income_10000_to_15000
# S2503_households_percemt_with_income_100000_to_150000
# S2503_households_percemt_with_income_15000_to_20000
# S2503_households_percemt_with_income_20000_to_25000
# S2503_households_percemt_with_income_25000_to_35000
# S2503_households_percemt_with_income_35000_to_50000
# S2503_households_percemt_with_income_5000_to_10000
# S2503_households_percemt_with_income_50000_to_75000
# S2503_households_percemt_with_income_75000_to_100000
# S2503_households_percemt_with_income_over_150000
# S2503_households_percemt_with_income_under_5000
# S2503_housing_cost_percentage_for_incomes_20000_to_35000_20_to_29_percent
# S2503_housing_cost_percentage_for_incomes_20000_to_35000_over_30_percent
# S2503_housing_cost_percentage_for_incomes_20000_to_35000_under_20_percent
# S2503_housing_cost_percentage_for_incomes_35000_to_50000_20_to_29_percent
# S2503_housing_cost_percentage_for_incomes_35000_to_50000_over_30_percent
# S2503_housing_cost_percentage_for_incomes_35000_to_50000_under_20_percent
# S2503_housing_cost_percentage_for_incomes_50000_to_75000_20_to_29_percent
# S2503_housing_cost_percentage_for_incomes_50000_to_75000_over_30_percent
# S2503_housing_cost_percentage_for_incomes_50000_to_75000_under_20_percent
# S2503_housing_cost_percentage_for_incomes_over_75000_20_to_29_percent
# S2503_housing_cost_percentage_for_incomes_over_75000_over_30_percent
# S2503_housing_cost_percentage_for_incomes_over_75000_under_20_percent
# S2503_housing_cost_percentage_for_incomes_under_20000_20_to_29_percent
# S2503_housing_cost_percentage_for_incomes_under_20000_over_30_percent
# S2503_housing_cost_percentage_for_incomes_under_20000_under_20_percent
# S2801_percentage_with_computer
# S2801_percentage_with_computing_device
# S2801_percentage_with_internet_subscription
# S2801_percentage_with_smartphone
# S2801_percentage_without_internet
# DP04_housing_median_room_count
# DP04_housing_owner_cost_as_percent_income
# DP04_rental_cost_15_to_20_percent_income
# DP04_rental_cost_20_to_25_percent_income
# DP04_rental_cost_25_to_30_percent_income
# DP04_rental_cost_30_to_35_percent_income
# DP04_rental_cost_35_or_more_percent_income
# DP04_rental_cost_less_than_15_percent_income
# DP04_rental_units_total
# DP04_vehicles_0
# DP04_vehicles_1
# DP04_vehicles_2
# DP04_vehicles_3_or_more
# DP04_vehicles_housing_total
# DP05_age_percent_10_to_14
# DP05_age_percent_15_to_19
# DP05_age_percent_20_to_24
# DP05_age_percent_25_to_34
# DP05_age_percent_35_to_44
# DP05_age_percent_45_to_54
# DP05_age_percent_5_to_9
# DP05_age_percent_55_to_59
# DP05_age_percent_60_to_64
# DP05_age_percent_65_to_74
# DP05_age_percent_75_to_84
# DP05_age_percent_over_85
# DP05_age_percent_under_5
# DP05_age_population_median_age
# B08121_median_income_other_means
# B08121_median_income_public_transit
# B08121_median_income_total
# B08121_median_income_vehicle_alone
# B08121_median_income_vehicle_carpool
# B08121_median_income_walked
# B08121_median_income_work_from_home
# B09001_population_12_to_14
# B09001_population_15_to_17
# B09001_population_3_to_4
# B09001_population_5
# B09001_population_6_to_8
# B09001_population_9_to_11
# B09001_population_under_18_total
# B09001_population_under_3
# B11012_households_cohabitation_with_under_18
# B11012_households_married_couple_with_under_18
# B11012_households_single_female_with_under_18
# B11012_households_single_male_with_under_18
# B11012_households_total
# B11016_family_households_2
# B11016_family_households_3
# B11016_family_households_4
# B11016_family_households_5
# B11016_family_households_6
# B11016_family_households_7_or_more
# B11016_family_households_total
# B13002_fertile_women_given_birth
# B13002_fertile_women_total
# -->

# %% [markdown]
# ##### acs_df filters intersects_per_road_length, population_density, and acs data from export_df

# %%
acs_df = export_df[[
    'intersects_per_road_length',
    'population_density',
    'S2302_families_no_worker',
    'S2302_families_no_worker_percent',
    'S2303_population_16_to_64_no_work',
    'S2303_population_16_to_64_no_work_percent',
    'S2303_population_16_to_64_total',
    'S1901_households_mean_income',
    'S1901_households_median_income',
    'S1901_households_total',
    'S1101_household_1_unit_structure',
    'S1101_household_2_unit_structure',
    'S1101_household_average_size',
    'S1101_household_living_alone',
    'S1101_household_living_alone_over_65',
    'S1101_household_mobile_misc_homes',
    'S1101_household_one_or_more_over_60',
    'S1101_household_one_or_more_under_18',
    'S1101_household_total_married',
    'S1101_household_with_under_18',
    'S1101_households_total',
    'S1401_population_enrolled_in_graduate',
    'S1401_population_enrolled_in_preschool',
    'S1401_population_enrolled_in_school',
    'S1401_population_enrolled_in_standardschool',
    'S1401_population_enrolled_in_undergraduate',
    'S1701_population_poverty_18_to_64',
    'S1701_population_poverty_female',
    'S1701_population_poverty_male',
    'S1701_population_poverty_over_65',
    'S1701_population_poverty_over25_baschelors_degree',
    'S1701_population_poverty_over25_highschool',
    'S1701_population_poverty_over25_no_highschool',
    'S1701_population_poverty_over25_some_college',
    'S1701_population_poverty_over25_total',
    'S1701_population_poverty_total',
    'S1701_population_poverty_under_18',
    'S1702_family_poverty_home_owner',
    'S1702_family_poverty_home_renter',
    'S1702_family_poverty_total',
    'S1301_omen_total_15_to_50',
    'S1501_population_over_25_completed_graduate',
    'S1501_population_over_25_completed_highschool',
    'S1501_population_over_25_completed_undergraduate',
    'S1501_population_over_25_some_highschool',
    'S1501_population_over_25_some_undergraduates',
    'S1501_population_over_25_total',
    'S2501_household_total',
    'S2501_household_with_relative_under_18',
    'S2502_household_moved_into_1990_to_1999',
    'S2502_household_moved_into_2000_to_2009',
    'S2502_household_moved_into_2010_to_2014',
    'S2502_household_moved_into_2015_to_2018',
    'S2502_household_moved_into_after_2019',
    'S2502_household_moved_into_before_1989',
    'S2502_householder_age_35_to_44',
    'S2502_householder_age_45_to_54',
    'S2502_householder_age_55_to_64',
    'S2502_householder_age_65_to_74',
    'S2502_householder_age_75_to_84',
    'S2502_householder_age_over_85',
    'S2502_householder_age_under_35',
    'S2502_householder_education_highschool',
    'S2502_householder_education_no_highschool',
    'S2502_householder_education_over_undergraduates',
    'S2502_householder_education_some_college_or_associates',
    'S2502_households_occupied_total',
    'S2503_households_percemt_median_income',
    'S2503_households_percemt_total',
    'S2503_households_percemt_with_income_10000_to_15000',
    'S2503_households_percemt_with_income_100000_to_150000',
    'S2503_households_percemt_with_income_15000_to_20000',
    'S2503_households_percemt_with_income_20000_to_25000',
    'S2503_households_percemt_with_income_25000_to_35000',
    'S2503_households_percemt_with_income_35000_to_50000',
    'S2503_households_percemt_with_income_5000_to_10000',
    'S2503_households_percemt_with_income_50000_to_75000',
    'S2503_households_percemt_with_income_75000_to_100000',
    'S2503_households_percemt_with_income_over_150000',
    'S2503_households_percemt_with_income_under_5000',
    'S2503_housing_cost_percentage_for_incomes_20000_to_35000_20_to_29_percent',
    'S2503_housing_cost_percentage_for_incomes_20000_to_35000_over_30_percent',
    'S2503_housing_cost_percentage_for_incomes_20000_to_35000_under_20_percent',
    'S2503_housing_cost_percentage_for_incomes_35000_to_50000_20_to_29_percent',
    'S2503_housing_cost_percentage_for_incomes_35000_to_50000_over_30_percent',
    'S2503_housing_cost_percentage_for_incomes_35000_to_50000_under_20_percent',
    'S2503_housing_cost_percentage_for_incomes_50000_to_75000_20_to_29_percent',
    'S2503_housing_cost_percentage_for_incomes_50000_to_75000_over_30_percent',
    'S2503_housing_cost_percentage_for_incomes_50000_to_75000_under_20_percent',
    'S2503_housing_cost_percentage_for_incomes_over_75000_20_to_29_percent',
    'S2503_housing_cost_percentage_for_incomes_over_75000_over_30_percent',
    'S2503_housing_cost_percentage_for_incomes_over_75000_under_20_percent',
    'S2503_housing_cost_percentage_for_incomes_under_20000_20_to_29_percent',
    'S2503_housing_cost_percentage_for_incomes_under_20000_over_30_percent',
    'S2503_housing_cost_percentage_for_incomes_under_20000_under_20_percent',
    'S2801_percentage_with_computer',
    'S2801_percentage_with_computing_device',
    'S2801_percentage_with_internet_subscription',
    'S2801_percentage_with_smartphone',
    'S2801_percentage_without_internet',
    'DP04_housing_median_room_count',
    'DP04_housing_owner_cost_as_percent_income',
    'DP04_rental_cost_15_to_20_percent_income',
    'DP04_rental_cost_20_to_25_percent_income',
    'DP04_rental_cost_25_to_30_percent_income',
    'DP04_rental_cost_30_to_35_percent_income',
    'DP04_rental_cost_35_or_more_percent_income',
    'DP04_rental_cost_less_than_15_percent_income',
    'DP04_rental_units_total',
    'DP04_vehicles_0',
    'DP04_vehicles_1',
    'DP04_vehicles_2',
    'DP04_vehicles_3_or_more',
    'DP04_vehicles_housing_total',
    'DP05_age_percent_10_to_14',
    'DP05_age_percent_15_to_19',
    'DP05_age_percent_20_to_24',
    'DP05_age_percent_25_to_34',
    'DP05_age_percent_35_to_44',
    'DP05_age_percent_45_to_54',
    'DP05_age_percent_5_to_9',
    'DP05_age_percent_55_to_59',
    'DP05_age_percent_60_to_64',
    'DP05_age_percent_65_to_74',
    'DP05_age_percent_75_to_84',
    'DP05_age_percent_over_85',
    'DP05_age_percent_under_5',
    'DP05_age_population_median_age',
    'B08121_median_income_other_means',
    'B08121_median_income_public_transit',
    'B08121_median_income_total',
    'B08121_median_income_vehicle_alone',
    'B08121_median_income_vehicle_carpool',
    'B08121_median_income_walked',
    'B08121_median_income_work_from_home',
    'B09001_population_12_to_14',
    'B09001_population_15_to_17',
    'B09001_population_3_to_4',
    'B09001_population_5',
    'B09001_population_6_to_8',
    'B09001_population_9_to_11',
    'B09001_population_under_18_total',
    'B09001_population_under_3',
    'B11012_households_cohabitation_with_under_18',
    'B11012_households_married_couple_with_under_18',
    'B11012_households_single_female_with_under_18',
    'B11012_households_single_male_with_under_18',
    'B11012_households_total',
    'B11016_family_households_2',
    'B11016_family_households_3',
    'B11016_family_households_4',
    'B11016_family_households_5',
    'B11016_family_households_6',
    'B11016_family_households_7_or_more',
    'B11016_family_households_total',
    'B13002_fertile_women_given_birth',
    'B13002_fertile_women_total',
]]

# %% [markdown]
# # Analyse ACS Data

# %%
# x = acs_df['intersects_per_road_length']
# y = acs_df['population_density']
# acs_df['population_density/intersect_density'] = y/x

acs_df['population_density/intersect_density'] = acs_df['population_density'] / acs_df['intersects_per_road_length']
acs_df['log_population_density'] = np.log(acs_df['population_density'])
acs_df['log_intersect_density'] = np.log(acs_df['intersects_per_road_length'])

acs_df['log_population_density/log_intersect_density'] = acs_df['log_population_density'] / acs_df['log_intersect_density']

acs_df['target'] = acs_df['log_population_density/log_intersect_density']

# acs_df['log_intersect_density/population_density'] = np.log(acs_df['intersect_density/population_density'])

acs_df.head()
# Out:
# C:\Users\cjong\AppData\Local\Temp\ipykernel_16424\4071223415.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   acs_df['population_density/intersect_density'] = acs_df['population_density'] / acs_df['intersects_per_road_length']
# C:\Users\cjong\AppData\Local\Temp\ipykernel_16424\4071223415.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   acs_df['log_population_density'] = np.log(acs_df['population_density'])
# ...

# %%
lm_rep = smf.ols(formula = 'target ~ B09001_population_12_to_14', data = acs_df).fit()
print (lm_rep.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.2390
# Date:                Tue, 01 Nov 2022   Prob (F-statistic):              0.625
# Time:                        14:25:10   Log-Likelihood:                -17786.
# No. Observations:                3143   AIC:                         3.558e+04
# Df Residuals:                    3141   BIC:                         3.559e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      7.1001      1.297      5.475      0.000       4.557       9.643
# ...
